# %% [markdown]
# ## Sanitizing
#
#
# - We want to reduce file sizes as much as possible, after normalizing (partz of original)
#     - DROP unneded colz

# %%
import pandas as pd

#month = "2019-Oct"
#month = "2019-Nov"
#month = "2019-Dec"
#month = "2020-Jan"
#month = "2020-Feb"
#month = "2020-Mar"
month = "2020-Apr"
fld = "../Dta/original_big/"
sfx = "_red.csv"
san = "_san.csv"

file = f"{fld}{month}{sfx}"
file_san = f"{fld}{month}{san}"


file
df = pd.read_csv(file)

dst_fld = '../Dta/agg/'

df.head(6)
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           0  2020-04-01 00:00:00 UTC       view     1201465
# 1           1  2020-04-01 00:00:01 UTC       view     1307156
# 2           2  2020-04-01 00:00:01 UTC       view     1480477
# 3           3  2020-04-01 00:00:02 UTC       view     1307050
# 4           4  2020-04-01 00:00:03 UTC       view     9500109
# 5           5  2020-04-01 00:00:03 UTC       view   100068493
#
#            category_id                     category_code     brand    price  \
# 0  2232732101407408685             apparel.shoes.slipons   samsung   230.38
# 1  2053013554658804075       electronics.audio.headphone     apple  1352.67
# 2  2053013563835941749  appliances.kitchen.refrigerators     apple  1184.05
# 3  2053013554658804075       electronics.audio.headphone     apple  1724.34
# 4  2232732104175649385                     apparel.scarf  defender    25.05
# ...

# %% [markdown]
# ### Save only needed colz after norm

# %%
df["evt"] = df["event_type"].str[:1]
df.head()
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           0  2020-04-01 00:00:00 UTC       view     1201465
# 1           1  2020-04-01 00:00:01 UTC       view     1307156
# 2           2  2020-04-01 00:00:01 UTC       view     1480477
# 3           3  2020-04-01 00:00:02 UTC       view     1307050
# 4           4  2020-04-01 00:00:03 UTC       view     9500109
#
#            category_id                     category_code     brand    price  \
# 0  2232732101407408685             apparel.shoes.slipons   samsung   230.38
# 1  2053013554658804075       electronics.audio.headphone     apple  1352.67
# 2  2053013563835941749  appliances.kitchen.refrigerators     apple  1184.05
# 3  2053013554658804075       electronics.audio.headphone     apple  1724.34
# 4  2232732104175649385                     apparel.scarf  defender    25.05
#
#      user_id                          user_session        date evt
# 0  568984877  e2456cef-2d4f-42b9-a53a-8893cb0c6851  2020-04-01   v
# ...

# %%
df["evt"].unique()
# Out:
# array(['v', 'p', 'c'], dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session', 'date',
#        'evt'],
#       dtype='object')

# %%
# temp save for comparison
# We are **not** interested, if user was logged in -> only anonymous sessions!!
san = "_san.csv"
file_san = f"{fld}{month}{san}"
print(file_san)

df[
    ["date", "evt", "product_id", "category_id", "brand", "price", "user_session"]
].to_csv(file_san)
# Out:
# ../Dta/original_big/2020-Apr_san.csv

# %%
df.head()
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           0  2020-04-01 00:00:00 UTC       view     1201465
# 1           1  2020-04-01 00:00:01 UTC       view     1307156
# 2           2  2020-04-01 00:00:01 UTC       view     1480477
# 3           3  2020-04-01 00:00:02 UTC       view     1307050
# 4           4  2020-04-01 00:00:03 UTC       view     9500109
#
#            category_id                     category_code     brand    price  \
# 0  2232732101407408685             apparel.shoes.slipons   samsung   230.38
# 1  2053013554658804075       electronics.audio.headphone     apple  1352.67
# 2  2053013563835941749  appliances.kitchen.refrigerators     apple  1184.05
# 3  2053013554658804075       electronics.audio.headphone     apple  1724.34
# 4  2232732104175649385                     apparel.scarf  defender    25.05
#
#      user_id                          user_session        date evt
# 0  568984877  e2456cef-2d4f-42b9-a53a-8893cb0c6851  2020-04-01   v
# ...
