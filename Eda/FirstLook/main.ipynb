# %% [markdown]
# # Eda
#
# ## First Look

# %%
import pandas as pd
import numpy as np

fld = "../../Dta/Big/"

month = "2019-Nov"
# month = "2019-Oct"
# month = "2019-Dec"

# month = "2020-Jan"
# month = "2020-feb"
# month = "2020-Mar"
# month = "2020-Apr"

# %%
df = pd.read_csv("../../Dta/Big/2019-Oct_part.csv")
df_2 = df[['category_id', 'category_code']]
df_2.to_csv(f"{fld}catz.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../../Dta/Big/2019-Oct_part.csv")
#       2 df_2 = df[['category_id', 'category_code']]
#       3 df_2.to_csv(f"{fld}catz.csv", index=False)
#
# ...

# %% [markdown]
# ## Sanitizing
#
# - ```event_time``` to ```date```
# - drop na

# %%
df['date'] = pd.to_datetime(df['event_time'].str[0:10])
len(df)
df.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session', 'date'],
#       dtype='object')

# %%
df.dropna(inplace=True)
len(df)
df[['date', 'event_type', 'product_id', 'category_id', 'brand', 'price', 'user_id', 'user_session', ]].to_csv("../../Dta/Big/tmp.csv", index=False)
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770940
# 1  2019-10-01 00:00:11 UTC       view     1004545  2053013555631882750
# 2  2019-10-01 00:00:20 UTC       view     4803399  2053013554658803970
# 4  2019-10-01 00:00:33 UTC       view    28717908  2053013565782098940
# 5  2019-10-01 00:00:37 UTC       view     1701111  2053013553031414020
#
#                          category_code         brand   price    user_id  \
# 0  appliances.environment.water_heater          aqua   33.20  554748717
# 1               electronics.smartphone        huawei  566.01  537918940
# 2          electronics.audio.headphone           jbl   33.21  555428858
# 4                        apparel.shoes  burgerschuhe  102.45  513798668
# 5        computers.peripherals.monitor          acer  514.79  547028884
#
#                            user_session       date
# 0  9333dfbd-b87a-4708-9857-6336556b0fcc 2019-10-01
# ...

# %% [markdown]
# ## Working with temp for further exploration

# %%
df = pd.read_csv("../../Dta/Big/tmp.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("../../Dta/Big/tmp.csv")
#       2 df.head()
#
# File ~/projects/gesundheit/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# unique brands
brands = df["brand"].unique()
catz = df["category_id"].unique()
len(catz)
# Out:
# 246
